# %%
from temul.polarisation import (
    get_strain_gradient, plot_polarisation_vectors)

import atomap.api as am
import hyperspy.api as hs
# Out:
# WARNING:hyperspy_gui_traitsui:The module://ipykernel.pylab.backend_inline matplotlib backend is not compatible with the traitsui GUI elements. For more information, read http://hyperspy.readthedocs.io/en/stable/user_guide/getting_started.html#possible-warnings-when-importing-hyperspy.
# WARNING:hyperspy_gui_traitsui:The traitsui GUI elements are not available.

# %%
from temul.polarisation import get_strain_gradient
import atomap.api as am
import hyperspy.api as hs

# %%
from temul.polarisation import get_strain_gradient
import atomap.api as am
import hyperspy.api as hs
# Out:
# WARNING:hyperspy_gui_traitsui:The module://ipykernel.pylab.backend_inline matplotlib backend is not compatible with the traitsui GUI elements. For more information, read http://hyperspy.readthedocs.io/en/stable/user_guide/getting_started.html#possible-warnings-when-importing-hyperspy.
# WARNING:hyperspy_gui_traitsui:The traitsui GUI elements are not available.

# %%
# Open the original PTO/SRO dataset

# %%
# Open the original PTO/SRO dataset

# %%
image = hs.load('name')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\eocli\Documents\Personal\code\python\TEMUL\publication_examples\PTO_marios_hadj\PTO_walkthrough_simple.py in <module>
# ----> <a href='file://c:\Users\eocli\Documents\Personal\code\python\TEMUL\publication_examples\PTO_marios_hadj\PTO_walkthrough_simple.py?line=6'>7</a> image = hs.load('name')
#
# ~\miniconda3\lib\site-packages\hyperspy\io.py in load(filenames, signal_type, stack, stack_axis, new_axis_name, lazy, convert_units, escape_square_brackets, **kwds)
#     273
#     274         if not filenames:
# --> 275             raise ValueError('No filename matches this pattern')
#     276
#     277     elif not isinstance(filenames, (list, tuple)):
#
# ValueError: No filename matches this pattern

# %%
# Open the pre-made PTO atom lattice. 
# See the extended walkthrough for how to make this atom lattice.

# %%
atom_lattice = am.load_atom_lattice_from_hdf5("Atom_Lattice.hdf5")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# c:\Users\eocli\Documents\Personal\code\python\TEMUL\publication_examples\PTO_marios_hadj\PTO_walkthrough_simple.py in <module>
# ----> <a href='file://c:\Users\eocli\Documents\Personal\code\python\TEMUL\publication_examples\PTO_marios_hadj\PTO_walkthrough_simple.py?line=10'>11</a> atom_lattice = am.load_atom_lattice_from_hdf5("Atom_Lattice.hdf5")
#
# ~\miniconda3\lib\site-packages\atomap\io.py in load_atom_lattice_from_hdf5(filename, construct_zone_axes)
#      25
#      26     """
# ---> 27     h5f = h5py.File(filename, 'r')
#      28
#      29     if 'atom_lattice_type' in h5f.attrs.keys():
#
# ~\miniconda3\lib\site-packages\h5py\_hl\files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, **kwds)
#     404             with phil:
#     405                 fapl = make_fapl(driver, libver, rdcc_nslots, rdcc_nbytes, rdcc_w0, **kwds)
# --> 406                 fid = make_fid(name, mode, userblock_size,
#     407                                fapl, fcpl=make_fcpl(track_order=track_order),
#     408                                swmr=swmr)
#
# ~\miniconda3\lib\site-packages\h5py\_hl\files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     171         if swmr and swmr_support:
#     172             flags |= h5f.ACC_SWMR_READ
# --> 173         fid = h5f.open(name, flags, fapl=fapl)
#     174     elif mode == 'r+':
#     175         fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# h5py\_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py\_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py\h5f.pyx in h5py.h5f.open()
#
# OSError: Unable to open file (unable to open file: name = 'Atom_Lattice.hdf5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)

# %%
sublattice1 = atom_lattice.sublattice_list[0] #  PTO Sublattice
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\eocli\Documents\Personal\code\python\TEMUL\publication_examples\PTO_marios_hadj\PTO_walkthrough_simple.py in <module>
# ----> <a href='file://c:\Users\eocli\Documents\Personal\code\python\TEMUL\publication_examples\PTO_marios_hadj\PTO_walkthrough_simple.py?line=11'>12</a> sublattice1 = atom_lattice.sublattice_list[0] #  PTO Sublattice
#
# NameError: name 'atom_lattice' is not defined

# %%
sublattice2 = atom_lattice.sublattice_list[1] #  SRO Sublattice
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\eocli\Documents\Personal\code\python\TEMUL\publication_examples\PTO_marios_hadj\PTO_walkthrough_simple.py in <module>
# ----> <a href='file://c:\Users\eocli\Documents\Personal\code\python\TEMUL\publication_examples\PTO_marios_hadj\PTO_walkthrough_simple.py?line=12'>13</a> sublattice2 = atom_lattice.sublattice_list[1] #  SRO Sublattice
#
# NameError: name 'atom_lattice' is not defined

# %%
# Plot the sublattice planes to see which zone_vector_index we use

# %%
sublattice2.construct_zone_axes()
sublattice2.plot_planes()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\eocli\Documents\Personal\code\python\TEMUL\publication_examples\PTO_marios_hadj\PTO_walkthrough_simple.py in <module>
# ----> <a href='file://c:\Users\eocli\Documents\Personal\code\python\TEMUL\publication_examples\PTO_marios_hadj\PTO_walkthrough_simple.py?line=15'>16</a> sublattice2.construct_zone_axes()
#       <a href='file://c:\Users\eocli\Documents\Personal\code\python\TEMUL\publication_examples\PTO_marios_hadj\PTO_walkthrough_simple.py?line=16'>17</a> sublattice2.plot_planes()
#
# NameError: name 'sublattice2' is not defined

# %%
# Set up parameters for get_strain_gradient

zone_vector_index = 0
atom_planes = (14, 19) #  chooses the starting and ending atom planes
sampling = image.axes_manager[-1].scale
units = image.axes_manager[-1].units
vmin, vmax = 1, 4
cmap = 'inferno' #  see matplotlib and colorcet for more colormaps
title = 'Strain Gradient Map'
filename = None #  Set to a string if you want to save the map
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\eocli\Documents\Personal\code\python\TEMUL\publication_examples\PTO_marios_hadj\PTO_walkthrough_simple.py in <module>
#       <a href='file://c:\Users\eocli\Documents\Personal\code\python\TEMUL\publication_examples\PTO_marios_hadj\PTO_walkthrough_simple.py?line=19'>20</a> zone_vector_index = 0
#       <a href='file://c:\Users\eocli\Documents\Personal\code\python\TEMUL\publication_examples\PTO_marios_hadj\PTO_walkthrough_simple.py?line=20'>21</a> atom_planes = (14, 19) #  chooses the starting and ending atom planes
# ----> <a href='file://c:\Users\eocli\Documents\Personal\code\python\TEMUL\publication_examples\PTO_marios_hadj\PTO_walkthrough_simple.py?line=21'>22</a> sampling = image.axes_manager[-1].scale
#       <a href='file://c:\Users\eocli\Documents\Personal\code\python\TEMUL\publication_examples\PTO_marios_hadj\PTO_walkthrough_simple.py?line=22'>23</a> units = image.axes_manager[-1].units
#       <a href='file://c:\Users\eocli\Documents\Personal\code\python\TEMUL\publication_examples\PTO_marios_hadj\PTO_walkthrough_simple.py?line=23'>24</a> vmin, vmax = 1, 4
#
# NameError: name 'image' is not defined

# %%
# We want to see the strain gradient in the SRO Sublattice

str_grad_map = get_strain_gradient(sublattice2, zone_vector_index, atom_planes,
                                   sampling, units, cmap, title)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\eocli\Documents\Personal\code\python\TEMUL\publication_examples\PTO_marios_hadj\PTO_walkthrough_simple.py in <module>
#       <a href='file://c:\Users\eocli\Documents\Personal\code\python\TEMUL\publication_examples\PTO_marios_hadj\PTO_walkthrough_simple.py?line=28'>29</a> # We want to see the strain gradient in the SRO Sublattice
#       <a href='file://c:\Users\eocli\Documents\Personal\code\python\TEMUL\publication_examples\PTO_marios_hadj\PTO_walkthrough_simple.py?line=29'>30</a>
# ----> <a href='file://c:\Users\eocli\Documents\Personal\code\python\TEMUL\publication_examples\PTO_marios_hadj\PTO_walkthrough_simple.py?line=30'>31</a> str_grad_map = get_strain_gradient(sublattice2, zone_vector_index, atom_planes,
#       <a href='file://c:\Users\eocli\Documents\Personal\code\python\TEMUL\publication_examples\PTO_marios_hadj\PTO_walkthrough_simple.py?line=31'>32</a>                                    sampling, units, cmap, title)
#
# NameError: name 'sublattice2' is not defined
